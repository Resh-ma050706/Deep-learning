# %% [markdown]
# <a href="https://colab.research.google.com/github/Resh-ma050706/Deep-learning/blob/main/24BAD097_EXP_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TASK A: VISUALIZATION OF ACTIVATION FUNCTIONS

import numpy as np
import matplotlib.pyplot as plt
print("Student Name : S.RESHMA")
print("Roll Number  : 24BAD097")
print("Task A: Visualization of Activation Functions")
# Input values
x = np.linspace(-10, 10, 200)
# Activation functions
sigmoid = 1 / (1 + np.exp(-x))
tanh = np.tanh(x)
relu = np.maximum(0, x)
# Plot
plt.figure(figsize=(6,4))
plt.plot(x, sigmoid, label="Sigmoid")
plt.plot(x, tanh, label="Tanh")
plt.plot(x, relu, label="ReLU")
plt.title("Activation Functions")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Student Name : S.RESHMA
# Roll Number  : 24BAD097
# Task A: Visualization of Activation Functions

# %%
# TASK B: PERFORMANCE COMPARISON OF ACTIVATION FUNCTIONS

import tensorflow as tf
import matplotlib.pyplot as plt
# Student Details
name = "S.RESHMA"
roll_no = "24BAD097"
print("Student Name :", name)
print("Roll Number  :", roll_no)
print("Task B: Performance Comparison of Activation Functions")
# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Normalize data
x_train = x_train / 255.0
x_test = x_test / 255.0
# Function to create model
def create_model(activation):
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(128, activation=activation),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model
# Train models
activations = ['sigmoid', 'tanh', 'relu']
histories = {}
for activation in activations:
    print("\nTraining with", activation, "activation...")
    model = create_model(activation)
    history = model.fit(
        x_train,
        y_train,
        epochs=5,
        batch_size=128,
        validation_split=0.2,
        verbose=1
    )
    histories[activation] = history
# Display final results
print("\nFINAL RESULTS")
print("-" * 50)
for activation in activations:
    history = histories[activation]
    train_acc = history.history['accuracy'][-1]
    val_acc = history.history['val_accuracy'][-1]
    train_loss = history.history['loss'][-1]
    val_loss = history.history['val_loss'][-1]
    print("\nActivation:", activation)
    print("Training Accuracy   :", round(train_acc, 4))
    print("Validation Accuracy :", round(val_acc, 4))
    print("Training Loss       :", round(train_loss, 4))
    print("Validation Loss     :", round(val_loss, 4))
# Accuracy comparison
plt.figure(figsize=(6,4))
for activation in activations:
    plt.plot(
        histories[activation].history['val_accuracy'],
        label=activation
    )
plt.title("Validation Accuracy Comparison")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Loss comparison
plt.figure(figsize=(6,4))
for activation in activations:
    plt.plot(
        histories[activation].history['val_loss'],
        label=activation
    )
plt.title("Validation Loss Comparison")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Student Name : S.RESHMA
# Roll Number  : 24BAD097
# Task B: Performance Comparison of Activation Functions
#
# Training with sigmoid activation...
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8471 - loss: 0.6668 - val_accuracy: 0.9131 - val_loss: 0.3302
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9151 - loss: 0.3067 - val_accuracy: 0.9296 - val_loss: 0.2588
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9304 - loss: 0.2469 - val_accuracy: 0.9388 - val_loss: 0.2199
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9399 - loss: 0.2092 - val_accuracy: 0.9456 - val_loss: 0.1969
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9481 - loss: 0.1818 - val_accuracy: 0.9503 - val_loss: 0.1773
#
# Training with tanh activation...
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8866 - loss: 0.4113 - val_accuracy: 0.9288 - val_loss: 0.2473
# Epoch 2/5
# ...

# %%
# TASK C: COMPARISON OF OPTIMIZATION ALGORITHMS

import tensorflow as tf
import matplotlib.pyplot as plt
# Student Details
name = "S.RESHMA"
roll_no = "24BAD097"
print("Student Name :", name)
print("Roll Number  :", roll_no)
print("Task C: Comparison of Optimization Algorithms")
# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Normalize data
x_train = x_train / 255.0
x_test = x_test / 255.0
# Create model
def create_model(optimizer):
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model
# Optimizers
optimizers = {
    "SGD": tf.keras.optimizers.SGD(learning_rate=0.01),
    "Momentum": tf.keras.optimizers.SGD(
        learning_rate=0.01,
        momentum=0.9
    ),
    "RMSProp": tf.keras.optimizers.RMSprop(learning_rate=0.001),
    "Adam": tf.keras.optimizers.Adam(learning_rate=0.001)
}
histories = {}
# Train models
for name_optimizer, optimizer in optimizers.items():
    print("\nTraining with", name_optimizer, "...")
    model = create_model(optimizer)
    history = model.fit(
        x_train,
        y_train,
        epochs=5,
        batch_size=128,
        validation_split=0.2,
        verbose=1
    )
    histories[name_optimizer] = history
# Display final results
print("\nFINAL RESULTS")
print("-" * 50)
for optimizer_name in optimizers:
    history = histories[optimizer_name]
    train_acc = history.history['accuracy'][-1]
    val_acc = history.history['val_accuracy'][-1]
    train_loss = history.history['loss'][-1]
    val_loss = history.history['val_loss'][-1]
    print("\nOptimizer:", optimizer_name)
    print("Training Accuracy   :", round(train_acc, 4))
    print("Validation Accuracy :", round(val_acc, 4))
    print("Training Loss       :", round(train_loss, 4))
    print("Validation Loss     :", round(val_loss, 4))
# Loss vs Epoch
plt.figure(figsize=(6,4))
for optimizer_name in optimizers:
    plt.plot(
        histories[optimizer_name].history['val_loss'],
        label=optimizer_name
    )
plt.title("Validation Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend()
plt.grid(True)
plt.show()
# Accuracy vs Epoch
plt.figure(figsize=(6,4))
for optimizer_name in optimizers:
    plt.plot(
        histories[optimizer_name].history['val_accuracy'],
        label=optimizer_name
    )
plt.title("Validation Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Student Name : S.RESHMA
# Roll Number  : 24BAD097
# Task C: Comparison of Optimization Algorithms
#
# Training with SGD ...
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6832 - loss: 1.3049 - val_accuracy: 0.8432 - val_loss: 0.7310
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8522 - loss: 0.6236 - val_accuracy: 0.8789 - val_loss: 0.4957
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8769 - loss: 0.4845 - val_accuracy: 0.8931 - val_loss: 0.4170
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8880 - loss: 0.4247 - val_accuracy: 0.9000 - val_loss: 0.3771
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8946 - loss: 0.3901 - val_accuracy: 0.9037 - val_loss: 0.3521
#
# Training with Momentum ...
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8476 - loss: 0.5477 - val_accuracy: 0.9153 - val_loss: 0.3007
# Epoch 2/5
# ...

# %%
# TASK D: DEEP LEARNING EXPERIMENT MANAGEMENT

from google.colab import drive
drive.mount('/content/drive')
name = "S.RESHMA"
roll_no = "24BAD097"
print("Student Name :", name)
print("Roll Number  :", roll_no)
print("Google Drive Mounted Successfully")
# Out:
# Mounted at /content/drive
# Student Name : S.RESHMA
# Roll Number  : 24BAD097
# Google Drive Mounted Successfully

# %%
import os
folder = "/content/drive/MyDrive/Deep_Learning_Experiment_24BAD097"
os.makedirs(folder, exist_ok=True)
print("Experiment folder created successfully!")
print("Folder:", folder)
# Out:
# Experiment folder created successfully!
# Folder: /content/drive/MyDrive/Deep_Learning_Experiment_24BAD097

# %%
import tensorflow as tf
# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0
# Create model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Train
model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=128,
    verbose=1
)
# Save model
model_path = "/content/drive/MyDrive/Deep_Learning_Experiment_24BAD097/mnist_model.keras"
model.save(model_path)
print("\nStudent Name :", "S.RESHMA")
print("Roll Number  :", "24BAD097")
print("Model saved successfully!")
print("Saved at:", model_path)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9022 - loss: 0.3574
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9520 - loss: 0.1682
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9640 - loss: 0.1234
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9722 - loss: 0.0948
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9775 - loss: 0.0770
#
# Student Name : S.RESHMA
# Roll Number  : 24BAD097
# Model saved successfully!
# Saved at: /content/drive/MyDrive/Deep_Learning_Experiment_24BAD097/mnist_model.keras

# %%
readme_content = """
# Deep Learning Experiment

"""
readme_path = "/content/drive/MyDrive/Deep_Learning_Experiment_24BAD097/README.md"
with open(readme_path, "w") as file:
    file.write(readme_content)

print("README.md created successfully!")
print("Student Name :", "S.RESHMA")
print("Roll Number  :", "24BAD097")
# Out:
# README.md created successfully!
# Student Name : S.RESHMA
# Roll Number  : 24BAD097
